# %% [markdown]
# # Lab 4: Introduction to Python Environments
# ## Anaconda & Jupyter Notebook
#
# This lab introduces **Anaconda** and **JupyterLab/Notebook, which we will use throughout the course.

# %% [markdown]
# ## Learning Objectives
# - Launch Jupyter Notebook using Anaconda
# - Create and run Python code cells
# - Use basic Python syntax
# - Work with common Python data types

# %% [markdown]
# ## 🔹 Part I — Getting Started with Jupyter Notebook
# Jupyter notebooks are made of **cells**.
# - Code cells execute Python
# - Markdown cells contain text

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %% [markdown]
# ## 🔹 Part II — Basic Python Syntax

# %%
# Printing output
print("Welcome to Python!")

# Variables
x = 10
y = 5

# Arithmetic
print(x + y)
print(x * y)
# Out:
# Welcome to Python!
# 15
# 50

# %% [markdown]
# ## 🔹 Part III — Python Data Types

# %%
# Numbers
a = 3
b = 2.5
print(a, b)

# Strings
name = "Student"
print("Hello,", name)

# Lists
nums = [1, 2, 3, 4]
print(nums)
# Out:
# 3 2.5
# Hello, Student
# [1, 2, 3, 4]

# %% [markdown]
# ## 🔹 Part IV — Input and Output

# %%
user = input("Enter your name: ")
print("Nice to meet you,", user)
# Out:
# Enter your name:  Tyler Ellington-Howell
# Nice to meet you, Tyler Ellington-Howell

# %% [markdown]
# ## Student Tasks
# Complete the tasks below.

# %% [markdown]
# ### Task 1 — Modify Output
# - Change the print statement to display your name.

# %%
print('My name is',user)
# Out:
# My name is Tyler Ellington-Howell

# %% [markdown]
# ### Task 2 — Variables
# - Create two numbers and print their sum and product.

# %%
# numbers
x = int(input("Enter first integer"))
y = int(input("Enter second integer"))
sum = x+y
product = x*y

print("Sum:",sum)
print("Product:",product)
# Out:
# Enter first integer 5
# Enter second integer 3
# Sum: 8
# Product: 15

# %% [markdown]
# ### Task 3 — Lists
# - Create a list of 5 numbers and print its length.

# %%
numList = [333, 22, 1]
print("This list contains",len(numList),"numbers")
# Out:
# This list contains 5 numbers

# %% [markdown]
# ### Task 4 — Reflection
# - Add a Markdown cell explaining what Jupyter Notebook is.

# %% [markdown]
# Jupyter Notebook is an environment that allows for documents to be create and shared with interactive code in addition to other features seen in most documenting software.
